# %%
from PIL import Image
import matplotlib.pyplot as  plt
import torch
import torchvision.transforms as transforms
import numpy as plt
from torchvision  import models

# %%
model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)

# %%
# Replace classifier for binary classification
num_features = model.classifier.in_features
model.classifier = torch.nn.Linear(num_features, 2)
print(model.classifier)
# Out:
# Linear(in_features=1024, out_features=2, bias=True)

# %%
# Image preprocessing
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
img = Image.open('x-ray-image-healthy-chest.webp').convert('RGB')
img= transform(img).unsqueeze(0)

# %%
with torch.no_grad():
    output  = model(img)
    prob = torch.softmax(output,dim=1)
    pred = torch.argmax(output,dim=1)

# %%
print(output,prob,pred)
# Out:
# tensor([[-0.0008, -0.2050]]) tensor([[0.5509, 0.4491]]) tensor([0])

# %%
classes = ["Normal", "Pneumonia"]

print("Prediction:", classes[pred.item()])
print("Confidence:", prob[0][pred.item()].item())
# Out:
# Prediction: Normal
# Confidence: 0.5508568286895752

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
import torch

print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.12.0+cpu
# None
# False

# %%
# Out:
# Current Working Directory: c:\Users\DELL\OneDrive\Desktop\medical-image-dashboard\ml\notebooks
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2
#       3 print("Current Working Directory:", os.getcwd())
# ----> 4 print("Model Path:", self.model_evaluation_config.model_path)
#       5 print("Exists:", os.path.exists(self.model_evaluation_config.model_path))
#
# NameError: name 'self' is not defined
